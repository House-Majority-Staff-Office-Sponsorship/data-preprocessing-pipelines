# %% [markdown]
# # ZIP → JSONL Pipeline (llama-cloud SDK)
#
# Converts a ZIP archive of documents (PDF, PPTX, DOCX) and images into a JSONL file ready for RAG ingestion using the `llama-cloud` `AsyncLlamaCloud` client.
#
# **Each JSONL record contains:**
# - `id` – stable MD5 hash of `source_file::page`
# - `title` – first heading found, or filename stem
# - `source_file` – original filename inside the ZIP
# - `file_type` – extension
# - `page_or_slide` – page number (when `SPLIT_BY="page"`)
# - `text` – extracted / AI-described markdown text
# - `metadata` – extra fields for filtering in your vector store
#
# ---
# ### Requirements
# ```
# pip install llama-cloud nest-asyncio python-dotenv jupyter
# ```
# Get API key at **https://cloud.llamaindex.ai**

# %%
import os
import zipfile
import json
import asyncio
import hashlib
import tempfile
import shutil
from pathlib import Path
from datetime import datetime, timezone
from collections import Counter

import nest_asyncio
nest_asyncio.apply()   # allow asyncio.run() inside Jupyter

from dotenv import load_dotenv
load_dotenv()

from llama_cloud import AsyncLlamaCloud

print("✅ Imports OK")
# Out:
# ✅ Imports OK

# %% [markdown]
# ## Configuration

# %%
# ── Paths ─────────────────────────────────────────────────────────────────────
ZIP_FILE_PATH = "pdfs.zip"       # ← path to ZIP file with training docs
OUTPUT_JSONL  = "rag_dataset2.jsonl"   # ← output JSONL path
EXTRACT_DIR   = tempfile.mkdtemp(prefix="zip_extracted_")

# ── LlamaCloud credentials ────────────────────────────────────────────────────
# Reads from .env first, falls back to the literal string below
LLAMA_API_KEY = os.getenv("LLAMA_CLOUD_API_KEY", "llx-Cew9ylAbHScLQlSNQXnPrCGRlomA8TVb9eCfViS3PszZmlsw")

# ── Parsing settings ──────────────────────────────────────────────────────────
# Tier options: "fast" | "cost_effective" | "agentic" | "agentic_plus"
# "agentic" is recommended — multimodal AI describes images/diagrams inline.
PARSE_TIER    = "agentic"
PARSE_VERSION = "latest"

# Splitting strategy:
#   "page" → one JSONL record per page/slide  (best granularity for RAG)
#   "file" → one JSONL record per file        (simpler, larger chunks)
SPLIT_BY = "page"

# ── Supported file types ──────────────────────────────────────────────────────
DOC_EXTENSIONS = {".pdf", ".pptx", ".ppt", ".docx", ".doc"}
IMG_EXTENSIONS = {".png", ".jpg", ".jpeg", ".gif", ".bmp", ".tiff", ".webp"}
ALL_SUPPORTED  = DOC_EXTENSIONS | IMG_EXTENSIONS

print(f"ZIP        : {ZIP_FILE_PATH}")
print(f"Output     : {OUTPUT_JSONL}")
print(f"Tier       : {PARSE_TIER} / {PARSE_VERSION}")
print(f"Split by   : {SPLIT_BY}")
print(f"Temp dir   : {EXTRACT_DIR}")
# Out:
# ZIP        : pdfs.zip
# Output     : rag_dataset2.jsonl
# Tier       : agentic / latest
# Split by   : page
# Temp dir   : /var/folders/hl/qvvm0zsx7k7b7c58jrfq3gkr0000gn/T/zip_extracted_ibrs_78v

# %% [markdown]
# ## Step 1 — Extract the ZIP

# %%
def extract_zip(zip_path: str, dest_dir: str) -> list[Path]:
    """Unzip and return paths of all supported files."""
    with zipfile.ZipFile(zip_path, "r") as zf:
        zf.extractall(dest_dir)

    all_files = list(Path(dest_dir).rglob("*"))
    supported = [
        f for f in all_files
        if f.is_file()
        and f.suffix.lower() in ALL_SUPPORTED
        and not f.name.startswith(".")   # skip macOS __MACOSX junk
    ]

    print(f"Found {len(all_files)} total files → {len(supported)} supported:")
    for f in supported:
        print(f"  ✔  {f.relative_to(dest_dir)}")
    return supported


supported_files = extract_zip(ZIP_FILE_PATH, EXTRACT_DIR)
# Out:
# Found 98 total files → 90 supported:
#   ✔  pdfs/82f8f37c_Directory.pdf
#   ✔  pdfs/8ea2a918_Guide.pdf
#   ✔  pdfs/a89ea872_Guide.pdf
#   ✔  pdfs/884f939a_Directory.pdf
#   ✔  pdfs/13be786e_Guide.pdf
#   ✔  pdfs/015fbe6f_Directory.pdf
#   ✔  pdfs/edd5c8a2_capitolhawaiigov.pdf
#   ✔  pdfs/20ac76b9_Download pdf httpslrbhawaiigovparwpconte.pdf
#   ✔  pdfs/12cf9a4c_Directory.pdf
#   ✔  pdfs/0cf107d6_Guide.pdf
#   ✔  pdfs/b758c9cb_Directory.pdf
#   ✔  pdfs/382cf6c9_Guide.pdf
#   ✔  pdfs/27cca961_Conference Rooms 2025 Conference.pdf
#   ✔  pdfs/cb44c2f7_Directory.pdf
#   ✔  pdfs/79405027_Which Deadlines Apply to My Bill.pdf
#   ✔  pdfs/36d63fa6_Directory.pdf
#   ✔  pdfs/9ff94a2b_Directory.pdf
#   ✔  pdfs/93128132_Guide.pdf
#   ✔  pdfs/eb29123d_Directory.pdf
#   ✔  pdfs/50cb5a1c_capitolhawaiigov.pdf
#   ✔  pdfs/defb481c_Session Calendar.pdf
#   ✔  pdfs/01e89b2a_Guide.pdf
#   ✔  pdfs/618c6a25_Directory.pdf
#   ✔  pdfs/1946beec_Directory.pdf
#   ✔  pdfs/e8827a10_Guide.pdf
#   ✔  pdfs/1c2eb86f_Guide.pdf
#   ✔  pdfs/16244f41_Guide.pdf
#   ✔  pdfs/ea21b413_Guide.pdf
#   ✔  pdfs/74255e4c_Guide.pdf
#   ✔  pdfs/1b02ef74_Directory.pdf
#   ✔  pdfs/37913e90_Directory.pdf
#   ✔  pdfs/047413af_Directory.pdf
#   ✔  pdfs/14c0b968_Guide.pdf
#   ✔  pdfs/66be7b27_Directory.pdf
#   ✔  pdfs/d5f49b58_Directory.pdf
#   ✔  pdfs/e7174410_capitolhawaiigov.pdf
#   ✔  pdfs/e3914131_DistributionTally Sheet.pdf
#   ✔  pdfs/9b411c1c_Guide.pdf
#   ✔  pdfs/bfa0b866_Directory.pdf
#   ✔  pdfs/0f595b3d_Pictures  Profiles.pdf
#   ✔  pdfs/9230f916_Leadership  Committees.pdf
#   ✔  pdfs/9e3475f3_Download pdf httpslrbhawaiigovparwpconte.pdf
#   ✔  pdfs/fa5dd85c_Directory.pdf
#   ✔  pdfs/d5c234c5_Download pdf httpslrbhawaiigovparwpconte.pdf
#   ✔  pdfs/f03c6178_Guide.pdf
#   ✔  pdfs/a6c6401f_Directory.pdf
#   ✔  pdfs/451207f6_Guide.pdf
#   ✔  pdfs/60de8e8d_Guide.pdf
#   ✔  pdfs/01f3684a_Guide.pdf
#   ✔  pdfs/1cba1114_Directory.pdf
#   ✔  pdfs/59ee39ab_Directory.pdf
#   ✔  pdfs/0d51ba83_InformationataGlance.pdf
#   ✔  pdfs/fabad318_Directory.pdf
#   ✔  pdfs/b6ca5cf5_Guide.pdf
#   ✔  pdfs/c632610a_Directory.pdf
#   ✔  pdfs/08bacf5e_Directory.pdf
#   ✔  pdfs/0df49e41_Directory.pdf
#   ✔  pdfs/a95b84c5_Pictures  Profiles.pdf
#   ✔  pdfs/26a25319_Guide.pdf
#   ✔  pdfs/2aa3b5b2_Guide.pdf
#   ✔  pdfs/dde54d70_Directory.pdf
#   ✔  pdfs/c040bfaf_Conference Procedures 2025 Conference.pdf
#   ✔  pdfs/90d2ca23_Directory.pdf
#   ✔  pdfs/f0117a6e_Directory.pdf
#   ✔  pdfs/8036c735_Directory.pdf
#   ✔  pdfs/0f0c1996_InformationataGlance.pdf
#   ✔  pdfs/dc3425f0_Directory.pdf
#   ✔  pdfs/c3f9f1b6_Guide.pdf
#   ✔  pdfs/d747ef74_Guide.pdf
#   ✔  pdfs/ee859716_Governors Deadlines 2026 Session.pdf
#   ✔  pdfs/ec4bffb5_Guide.pdf
#   ✔  pdfs/51a3f8bc_Guide.pdf
#   ✔  pdfs/1d47e5a5_Guide.pdf
#   ✔  pdfs/153a0b1e_Committee Clerks.pdf
#   ✔  pdfs/dc98ab3c_Office Managers.pdf
#   ✔  pdfs/a1696ee5_Guide.pdf
#   ✔  pdfs/62f882c9_Directory.pdf
#   ✔  pdfs/d5474333_Leadership  Committees.pdf
#   ✔  pdfs/f2d03492_Directory.pdf
#   ✔  pdfs/98ebff85_Guide.pdf
#   ✔  pdfs/28a731eb_Guide.pdf
#   ✔  pdfs/a09ed767_Guide.pdf
#   ✔  pdfs/9b4bb7b0_capitolhawaiigov.pdf
#   ✔  pdfs/08caece7_Directory.pdf
#   ✔  pdfs/635a11b1_Directory.pdf
#   ✔  pdfs/d4943c81_Guide.pdf
#   ✔  pdfs/f1ca50db_capitolhawaiigov.pdf
#   ✔  pdfs/ed99fdde_Guide.pdf
#   ✔  pdfs/89606c15_Legislative Directory RoomPhoneFaxEmail.pdf
#   ✔  pdfs/9c5acdb4_Guide.pdf

# %%
all_items = list(Path(EXTRACT_DIR).rglob("*"))
dirs  = [f for f in all_items if f.is_dir()]
files = [f for f in all_items if f.is_file() and not f.name.startswith(".")]

print(f"Directories : {len(dirs)}")
print(f"Files       : {len(files)}")
print(f"Supported   : {len(supported_files)}")
print(f"Unsupported : {len(files) - len(supported_files)}")

if len(files) - len(supported_files) > 0:
    unsupported = [f for f in files if f not in supported_files and not f.name.startswith(".")]
    for f in unsupported:
        print(f"  skipped: {f.name}")
# Out:
# Directories : 3
# Files       : 90
# Supported   : 90
# Unsupported : 0

# %% [markdown]
# ## Step 2 — Upload & parse with `AsyncLlamaCloud`
#
# The `agentic` tier uses multimodal AI that:
# - Extracts structured text from PDFs, PPTX, DOCX with full layout awareness
# - Generates natural-language descriptions for embedded images, charts, diagrams, and slides
# - Returns results as clean Markdown (`markdown_full`) and plain text (`text_full`)

# %%
def extract_title_from_markdown(md: str) -> str | None:
    """Return the first H1 or H2 heading found in a markdown string."""
    for line in md.splitlines():
        line = line.strip()
        if line.startswith("## "):
            return line[3:].strip()
        if line.startswith("# "):
            return line[2:].strip()
    return None


def make_id(source_file: str, page: int) -> str:
    """Stable MD5 identifier for a source_file + page combo."""
    return hashlib.md5(f"{source_file}::{page}".encode()).hexdigest()


def split_markdown_by_page(markdown_full: str) -> list[str]:
    """
    LlamaParse separates pages with a horizontal rule (---) in its markdown.
    Split on that delimiter to get per-page chunks.
    Falls back to the whole document as one chunk if no delimiter is found.
    """
    for delimiter in ["\n---\n", "\n\n---\n\n", "\n- - -\n"]:
        if delimiter in markdown_full:
            return [p.strip() for p in markdown_full.split(delimiter) if p.strip()]
    return [markdown_full.strip()]


async def parse_file(client: AsyncLlamaCloud, file_path: Path) -> list[dict]:
    """
    Upload one file to LlamaCloud, parse it, and return a list of
    page-level dicts: {page_or_slide, title, text}
    """
    # 1. Upload the file
    with open(file_path, "rb") as fh:
        file_obj = await client.files.create(
            file=(file_path.name, fh, "application/octet-stream"),
            purpose="parse",
        )

    # 2. Parse — same pattern as the reference snippet above
    result = await client.parsing.parse(
        file_id=file_obj.id,
        tier=PARSE_TIER,
        version=PARSE_VERSION,
        expand=["markdown_full", "text_full", "markdown"],
    )

    # 3. Prefer markdown_full for richness; fall back to text_full
    full_content = result.markdown_full or result.text_full or ""
    if not full_content.strip():
        return []

    # 4. Build page-level records
    if SPLIT_BY == "page":
        # Use per-page list from the API when available (most accurate)
        page_items = getattr(result, "markdown", None) or []
        if page_items and isinstance(page_items, list):
            chunks = [p for p in page_items if isinstance(p, str) and p.strip()]
        else:
            # Fall back to splitting markdown_full on LlamaParse page delimiters
            chunks = split_markdown_by_page(full_content)

        return [
            {
                "page_or_slide": i + 1,
                "title": extract_title_from_markdown(chunk) or file_path.stem,
                "text": chunk.strip(),
            }
            for i, chunk in enumerate(chunks)
        ]
    else:
        # SPLIT_BY == "file" — one record for the whole document
        return [{
            "page_or_slide": None,
            "title": extract_title_from_markdown(full_content) or file_path.stem,
            "text": full_content.strip(),
        }]


print("✅ Parsing helpers defined")
# Out:
# ✅ Parsing helpers defined

# %% [markdown]
# ## Step 3 — Run parsing (concurrent)

# %%
# Max files parsed at the same time.
# Raising this speeds things up but risks 'Client Closed Request' errors.
MAX_CONCURRENT = 5

# Tracks files that failed so we can report them clearly at the end.
failed_files: list[str] = []


async def parse_all(files: list[Path]) -> list[dict]:
    client    = AsyncLlamaCloud(api_key=LLAMA_API_KEY)
    semaphore = asyncio.Semaphore(MAX_CONCURRENT)
    records   = []

    async def parse_with_limit(file_path: Path):
        async with semaphore:                          # ← indented inside function
            for attempt in range(1, 4):
                try:
                    result = await parse_file(client, file_path)
                    if result:
                        return result
                except Exception as e:
                    if attempt < 3:
                        wait = attempt * 10
                        print(f"\n    ↻ retry {attempt}/3 after {wait}s ({e})")
                        await asyncio.sleep(wait)
                    else:
                        raise
            return []

    # Kick off all tasks — semaphore controls how many run at once
    tasks = {f: asyncio.create_task(parse_with_limit(f)) for f in files}

    for file_path, task in tasks.items():
        rel = str(file_path.relative_to(EXTRACT_DIR))
        ext = file_path.suffix.lower()
        print(f"  ⏳ {rel} ...", end=" ", flush=True)

        try:
            pages = await task
        except Exception as e:
            print(f"FAILED ({e})")
            failed_files.append(rel)
            continue

        if not pages:
            print("(empty result)")
            failed_files.append(rel)
            continue

        print(f"{len(pages)} page(s)")

        for p in pages:
            records.append({
                "id":            make_id(rel, p["page_or_slide"] or 0),
                "title":         p["title"],
                "source_file":   rel,
                "file_type":     ext.lstrip("."),
                "page_or_slide": p["page_or_slide"],
                "text":          p["text"],
                "metadata": {
                    "parse_tier": PARSE_TIER,
                    "parsed_at":  datetime.now(timezone.utc).isoformat(),
                },
            })

    return records


print(f"Parsing started (max {MAX_CONCURRENT} files at a time) ...")
records = asyncio.run(parse_all(supported_files))
print(f"\n✅ Done — {len(records)} JSONL records generated.")

if failed_files:
    print(f"\n⚠️  {len(failed_files)} file(s) failed and were skipped:")
    for f in failed_files:
        print(f"   ✗ {f}")
    print("\nRe-run the cell to retry.")
else:
    print("✅ All files parsed successfully — no failures.")
# Out:
# Parsing started (max 5 files at a time) ...
#   ⏳ pdfs/82f8f37c_Directory.pdf ... 14 page(s)
#   ⏳ pdfs/8ea2a918_Guide.pdf ... 8 page(s)
#   ⏳ pdfs/a89ea872_Guide.pdf ... 15 page(s)
#   ⏳ pdfs/884f939a_Directory.pdf ... 2 page(s)
#   ⏳ pdfs/13be786e_Guide.pdf ... 13 page(s)
#   ⏳ pdfs/015fbe6f_Directory.pdf ... 6 page(s)
#   ⏳ pdfs/edd5c8a2_capitolhawaiigov.pdf ... 2 page(s)
#   ⏳ pdfs/20ac76b9_Download pdf httpslrbhawaiigovparwpconte.pdf ... 1 page(s)
#   ⏳ pdfs/12cf9a4c_Directory.pdf ... 6 page(s)
#   ⏳ pdfs/0cf107d6_Guide.pdf ... 14 page(s)
#   ⏳ pdfs/b758c9cb_Directory.pdf ... 12 page(s)
#   ⏳ pdfs/382cf6c9_Guide.pdf ... 4 page(s)
#   ⏳ pdfs/27cca961_Conference Rooms 2025 Conference.pdf ... 1 page(s)
#   ⏳ pdfs/cb44c2f7_Directory.pdf ... 9 page(s)
#   ⏳ pdfs/79405027_Which Deadlines Apply to My Bill.pdf ... 2 page(s)
#   ⏳ pdfs/36d63fa6_Directory.pdf ... 14 page(s)
#   ⏳ pdfs/9ff94a2b_Directory.pdf ... 2 page(s)
#   ⏳ pdfs/93128132_Guide.pdf ... 22 page(s)
#   ⏳ pdfs/eb29123d_Directory.pdf ... 3 page(s)
#   ⏳ pdfs/50cb5a1c_capitolhawaiigov.pdf ... 76 page(s)
#   ⏳ pdfs/defb481c_Session Calendar.pdf ... 2 page(s)
#   ⏳ pdfs/01e89b2a_Guide.pdf ... 7 page(s)
#   ⏳ pdfs/618c6a25_Directory.pdf ... 2 page(s)
#   ⏳ pdfs/1946beec_Directory.pdf ... 1 page(s)
#   ⏳ pdfs/e8827a10_Guide.pdf ... 304 page(s)
#   ⏳ pdfs/1c2eb86f_Guide.pdf ... 12 page(s)
#   ⏳ pdfs/16244f41_Guide.pdf ... 4 page(s)
#   ⏳ pdfs/ea21b413_Guide.pdf ... 5 page(s)
#   ⏳ pdfs/74255e4c_Guide.pdf ... 12 page(s)
#   ⏳ pdfs/1b02ef74_Directory.pdf ... 3 page(s)
#   ⏳ pdfs/37913e90_Directory.pdf ... 2 page(s)
#   ⏳ pdfs/047413af_Directory.pdf ... 2 page(s)
#   ⏳ pdfs/14c0b968_Guide.pdf ... 15 page(s)
#   ⏳ pdfs/66be7b27_Directory.pdf ... 7 page(s)
#   ⏳ pdfs/d5f49b58_Directory.pdf ... 3 page(s)
#   ⏳ pdfs/e7174410_capitolhawaiigov.pdf ... 1 page(s)
#   ⏳ pdfs/e3914131_DistributionTally Sheet.pdf ... 1 page(s)
#   ⏳ pdfs/9b411c1c_Guide.pdf ... 11 page(s)
#   ⏳ pdfs/bfa0b866_Directory.pdf ... 10 page(s)
#   ⏳ pdfs/0f595b3d_Pictures  Profiles.pdf ... 6 page(s)
#   ⏳ pdfs/9230f916_Leadership  Committees.pdf ... 1 page(s)
#   ⏳ pdfs/9e3475f3_Download pdf httpslrbhawaiigovparwpconte.pdf ... 1 page(s)
#   ⏳ pdfs/fa5dd85c_Directory.pdf ... 3 page(s)
#   ⏳ pdfs/d5c234c5_Download pdf httpslrbhawaiigovparwpconte.pdf ... 1 page(s)
#   ⏳ pdfs/f03c6178_Guide.pdf ... 4 page(s)
#   ⏳ pdfs/a6c6401f_Directory.pdf ... 10 page(s)
#   ⏳ pdfs/451207f6_Guide.pdf ... 10 page(s)
#   ⏳ pdfs/60de8e8d_Guide.pdf ... 14 page(s)
#   ⏳ pdfs/01f3684a_Guide.pdf ... 14 page(s)
#   ⏳ pdfs/1cba1114_Directory.pdf ... 1 page(s)
#   ⏳ pdfs/59ee39ab_Directory.pdf ... 228 page(s)
#   ⏳ pdfs/0d51ba83_InformationataGlance.pdf ... 1 page(s)
#   ⏳ pdfs/fabad318_Directory.pdf ... 12 page(s)
#   ⏳ pdfs/b6ca5cf5_Guide.pdf ... 4 page(s)
#   ⏳ pdfs/c632610a_Directory.pdf ... 15 page(s)
#   ⏳ pdfs/08bacf5e_Directory.pdf ... 10 page(s)
#   ⏳ pdfs/0df49e41_Directory.pdf ... 10 page(s)
#   ⏳ pdfs/a95b84c5_Pictures  Profiles.pdf ... 11 page(s)
#   ⏳ pdfs/26a25319_Guide.pdf ... 9 page(s)
#   ⏳ pdfs/2aa3b5b2_Guide.pdf ... 1 page(s)
#   ⏳ pdfs/dde54d70_Directory.pdf ... 15 page(s)
#   ⏳ pdfs/c040bfaf_Conference Procedures 2025 Conference.pdf ... 6 page(s)
#   ⏳ pdfs/90d2ca23_Directory.pdf ... 2 page(s)
#   ⏳ pdfs/f0117a6e_Directory.pdf ... 4 page(s)
#   ⏳ pdfs/8036c735_Directory.pdf ... 5 page(s)
#   ⏳ pdfs/0f0c1996_InformationataGlance.pdf ... 1 page(s)
#   ⏳ pdfs/dc3425f0_Directory.pdf ... 3 page(s)
#   ⏳ pdfs/c3f9f1b6_Guide.pdf ... 19 page(s)
#   ⏳ pdfs/d747ef74_Guide.pdf ... 5 page(s)
#   ⏳ pdfs/ee859716_Governors Deadlines 2026 Session.pdf ... 1 page(s)
#   ⏳ pdfs/ec4bffb5_Guide.pdf ... 1 page(s)
#   ⏳ pdfs/51a3f8bc_Guide.pdf ... 3 page(s)
#   ⏳ pdfs/1d47e5a5_Guide.pdf ... 24 page(s)
#   ⏳ pdfs/153a0b1e_Committee Clerks.pdf ... 1 page(s)
#   ⏳ pdfs/dc98ab3c_Office Managers.pdf ... 2 page(s)
#   ⏳ pdfs/a1696ee5_Guide.pdf ... 7 page(s)
#   ⏳ pdfs/62f882c9_Directory.pdf ... 2 page(s)
#   ⏳ pdfs/d5474333_Leadership  Committees.pdf ... 2 page(s)
#   ⏳ pdfs/f2d03492_Directory.pdf ... 1 page(s)
#   ⏳ pdfs/98ebff85_Guide.pdf ... 6 page(s)
#   ⏳ pdfs/28a731eb_Guide.pdf ... 6 page(s)
#   ⏳ pdfs/a09ed767_Guide.pdf ... 5 page(s)
#   ⏳ pdfs/9b4bb7b0_capitolhawaiigov.pdf ... 3 page(s)
#   ⏳ pdfs/08caece7_Directory.pdf ... 8 page(s)
#   ⏳ pdfs/635a11b1_Directory.pdf ... 12 page(s)
#   ⏳ pdfs/d4943c81_Guide.pdf ... 8 page(s)
#   ⏳ pdfs/f1ca50db_capitolhawaiigov.pdf ... 41 page(s)
#   ⏳ pdfs/ed99fdde_Guide.pdf ... 2 page(s)
#   ⏳ pdfs/89606c15_Legislative Directory RoomPhoneFaxEmail.pdf ... 2 page(s)
#   ⏳ pdfs/9c5acdb4_Guide.pdf ... 4 page(s)
#
# ✅ Done — 1197 JSONL records generated.
# ✅ All files parsed successfully — no failures.

# %%
# ── Retry failed files with agentic_plus tier ─────────────────────────────────
if failed_files:
    print(f"Retrying {len(failed_files)} failed file(s) with 'agentic_plus' tier...\n")

    async def retry_with_agentic_plus():
        client  = AsyncLlamaCloud(api_key=LLAMA_API_KEY)
        recovered = []

        for rel in failed_files:
            file_path = Path(EXTRACT_DIR) / rel
            ext = file_path.suffix.lower()
            print(f"  ⏳ {rel} ...", end=" ", flush=True)

            for attempt in range(1, 4):
                try:
                    # Upload
                    with open(file_path, "rb") as fh:
                        file_obj = await client.files.create(
                            file=(file_path.name, fh, "application/octet-stream"),
                            purpose="parse",
                        )

                    # Parse with agentic_plus
                    result = await client.parsing.parse(
                        file_id=file_obj.id,
                        tier="agentic_plus",        # ← upgraded tier
                        version=PARSE_VERSION,
                        expand=["markdown_full", "text_full", "markdown"],
                    )

                    full_content = result.markdown_full or result.text_full or ""
                    if not full_content.strip():
                        raise ValueError("Empty result returned")

                    # Split into pages
                    page_items = getattr(result, "markdown", None) or []
                    if page_items and isinstance(page_items, list):
                        chunks = [p for p in page_items if isinstance(p, str) and p.strip()]
                    else:
                        chunks = split_markdown_by_page(full_content)

                    pages = [
                        {
                            "page_or_slide": i + 1,
                            "title": extract_title_from_markdown(chunk) or file_path.stem,
                            "text": chunk.strip(),
                        }
                        for i, chunk in enumerate(chunks)
                    ]

                    print(f"{len(pages)} page(s) ✅")

                    for p in pages:
                        recovered.append({
                            "id":            make_id(rel, p["page_or_slide"]),
                            "title":         p["title"],
                            "source_file":   rel,
                            "file_type":     ext.lstrip("."),
                            "page_or_slide": p["page_or_slide"],
                            "text":          p["text"],
                            "metadata": {
                                "parse_tier": "agentic_plus",
                                "parsed_at":  datetime.now(timezone.utc).isoformat(),
                            },
                        })
                    break  # success — stop retrying

                except Exception as e:
                    if attempt < 3:
                        wait = attempt * 10
                        print(f"\n    ↻ retry {attempt}/3 after {wait}s ({e})", end=" ")
                        await asyncio.sleep(wait)
                    else:
                        print(f"FAILED after 3 attempts ({e})")

        return recovered

    recovered_records = asyncio.run(retry_with_agentic_plus())

    if recovered_records:
        records.extend(recovered_records)
        print(f"\n✅ Recovered {len(recovered_records)} records — total now: {len(records)}")
        # Also append to the JSONL file
        with open(OUTPUT_JSONL, "a", encoding="utf-8") as f:
            for rec in recovered_records:
                f.write(json.dumps(rec, ensure_ascii=False) + "\n")
        print(f"✅ Appended to '{OUTPUT_JSONL}'")
    else:
        print("\n❌ File still failed with agentic_plus — the PDF itself may be corrupted or password-protected.")
else:
    print("✅ No failed files to retry.")
# Out:
# Retrying 1 failed file(s) with 'agentic_plus' tier...
#
#   ⏳ UH Capstone Training Files 2-16-26/PRESENTATION 2026 District CIP Training.pdf ... 6 page(s) ✅
#
# ✅ Recovered 6 records — total now: 919
# ✅ Appended to 'rag_dataset.jsonl'

# %% [markdown]
# ## Step 4 — Write JSONL output

# %%
with open(OUTPUT_JSONL, "w", encoding="utf-8") as f:
    for rec in records:
        f.write(json.dumps(rec, ensure_ascii=False) + "\n")

size_kb = Path(OUTPUT_JSONL).stat().st_size / 1024
print(f"✅ Wrote {len(records)} records → '{OUTPUT_JSONL}' ({size_kb:.1f} KB)")
# Out:
# ✅ Wrote 1197 records → 'rag_dataset2.jsonl' (3357.8 KB)

# %% [markdown]
# ## Step 5 — Preview & validate

# %%
# ── Stats ──────────────────────────────────────────────────────────────────────
type_counts = Counter(r["file_type"] for r in records)
total_chars = sum(len(r["text"]) for r in records)
avg_chars   = total_chars // max(len(records), 1)

print("Records by file type:")
for ft, cnt in type_counts.most_common():
    print(f"  {ft:8s}  {cnt} record(s)")
print(f"\nTotal characters : {total_chars:,}")
print(f"Avg chars/record : {avg_chars:,}")
# Out:
# Records by file type:
#   pdf       1197 record(s)
#
# Total characters : 3,048,361
# Avg chars/record : 2,546

# %%
# ── Preview first 3 records ────────────────────────────────────────────────────
for rec in records[:3]:
    print("─" * 64)
    print(f"ID          : {rec['id']}")
    print(f"Title       : {rec['title']}")
    print(f"Source      : {rec['source_file']}  (page {rec['page_or_slide']})")
    print(f"Type        : {rec['file_type']}")
    snippet = rec['text'][:300].replace('\n', ' ')
    print(f"Text snip   : {snippet}...")
    print()
# Out:
# ────────────────────────────────────────────────────────────────
# ID          : e9dca4b07fc6c608e2b8fd2568168709
# Title       : CITY AND COUNTY OF HONOLULU
# Source      : pdfs/82f8f37c_Directory.pdf  (page 1)
# Type        : pdf
# Text snip   : # CITY AND COUNTY OF HONOLULU https://honolulu.gov/  ## LEGISLATIVE BRANCH  Honolulu Hale 530 South King Street, Room 202 Honolulu, HI 96813  **CITY COUNCIL (9)** 808-768-5010 https://www.honolulucitycouncil.org/ **CHAIR/4<sup>TH</sup> DISTRICT** **TOMMY WATERS** (01-02-27) 808-768-5004 tommy.waters...
#
# ────────────────────────────────────────────────────────────────
# ID          : deeaf1498788b51b1a865a013013d781
# Title       : OFFICE OF THE CITY AUDITOR
# Source      : pdfs/82f8f37c_Directory.pdf  (page 2)
# Type        : pdf
# Text snip   : CITY AND COUNTY OF HONOLULU  # OFFICE OF THE CITY AUDITOR  Campbell Square,  1001 Kamokila Blvd., Ste. 216, Kapolei, HI 96707  https://honolulu.gov/auditor  ACTING CITY AUDITOR....................TROY SHIMASAKI......................................................... 808-768-3134 FAX: 808-768-3135 o...
#
# ────────────────────────────────────────────────────────────────
# ID          : b81402f4f8607e54283291e6d990fb99
# Title       : OFFICE OF THE MANAGING DIRECTOR
# Source      : pdfs/82f8f37c_Directory.pdf  (page 3)
# Type        : pdf
# Text snip   : CITY AND COUNTY OF HONOLULU  # OFFICE OF THE MANAGING DIRECTOR  https://www.honolulu.gov/mayor | Honolulu Hale, Rm. 306  * **MANAGING DIRECTOR**: MICHAEL FORMBY (808-768-4275) * **Deputy Managing Director**: Krishna F. Jayaram (808-768-4811) * **FAX**: 808-768-4242 * **Communications Director**: Sco...

# %%
# ── Reload & validate the written file ────────────────────────────────────────
required_keys = {"id", "title", "source_file", "file_type", "text", "metadata"}
loaded, bad   = [], []

with open(OUTPUT_JSONL, encoding="utf-8") as f:
    for i, line in enumerate(f):
        rec = json.loads(line)
        loaded.append(rec)
        if not required_keys.issubset(rec.keys()):
            bad.append(i)

assert len(loaded) == len(records), "Record count mismatch after reload!"

if bad:
    print(f"⚠️  {len(bad)} record(s) missing required keys at lines: {bad}")
else:
    print(f"✅ All {len(loaded)} records are valid — JSONL is ready for RAG ingestion!")
# Out:
# ✅ All 1197 records are valid — JSONL is ready for RAG ingestion!

# %% [markdown]
# ## Cleanup (optional)

# %%
# Uncomment to delete the temporary extraction directory when done
# shutil.rmtree(EXTRACT_DIR)
# print(f"Removed: {EXTRACT_DIR}")

# %% [markdown]
# ---
# ## JSONL Schema Reference
#
# | Field | Type | Description |
# |---|---|---|
# | `id` | string | Stable MD5 of `source_file::page` — safe to use as vector store doc ID |
# | `title` | string | First H1/H2 heading or filename stem |
# | `source_file` | string | Relative path inside the ZIP |
# | `file_type` | string | `pdf`, `pptx`, `docx`, `png`, … |
# | `page_or_slide` | int \| null | 1-indexed (null when `SPLIT_BY="file"`) |
# | `text` | string | Markdown text; images/diagrams described inline by the agentic parser |
# | `metadata` | object | `parse_tier`, `parsed_at` UTC timestamp |
#
# ## Next Steps — Load into a Vector Store
#
# ```python
# from llama_index.core import Document, VectorStoreIndex
#
# docs = []
# with open("rag_dataset.jsonl") as f:
#     for line in f:
#         r = json.loads(line)
#         docs.append(Document(
#             doc_id   = r["id"],
#             text     = r["text"],
#             metadata = {
#                 "title":  r["title"],
#                 "source": r["source_file"],
#                 "page":   r["page_or_slide"],
#                 **r["metadata"],
#             },
#         ))
#
# index = VectorStoreIndex.from_documents(docs)
# ```
